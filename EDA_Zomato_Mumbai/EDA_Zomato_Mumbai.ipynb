# %%
#Importing the required libraries for EDA
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.io as pio

# %%
#!pip install plotly

# %%
pio.renderers.default="svg"

# %%
#Importing the dataset
raw_df=pd.read_csv('Zomato_Mumbai_Dataset.csv', delimiter='|')
raw_df
# Out:
#                     NAME PRICE  \
# 0                Hitchki  1200
# 1           Baba Falooda   400
# 2          Chin Chin Chu  1800
# 3         Butterfly High  1000
# 4              BKC  DIVE  1200
# ...                  ...   ...
# 15076  Hari Om Snack Bar   350
# 15077           PitaBurg   400
# 15078     Uncha Otlawala   300
# 15079     Mandarin Panda   400
# 15080                     NaN
#
#                                          CUSINE_CATEGORY    CITY  \
# 0      Modern Indian,North Indian,Chinese,Momos,Birya...  Mumbai
# 1                           Desserts,Ice Cream,Beverages  Mumbai
# 2                                          Asian,Chinese  Mumbai
# 3                                          Modern Indian  Mumbai
# 4                       North Indian,Chinese,Continental  Mumbai
# ...                                                  ...     ...
# 15076                     Fast Food,South Indian,Chinese  Mumbai
# 15077                                 Fast Food,Lebanese  Mumbai
# 15078                                 Desserts,Ice Cream  Mumbai
# 15079                              Desserts,Chinese,Thai  Mumbai
# 15080                                                NaN     NaN
#
#                                                   REGION  \
# 0      First International Financial Centre-- Bandra ...
# 1                                                  Mahim
# 2                                                   Juhu
# 3                                   Bandra Kurla Complex
# 4                                   Bandra Kurla Complex
# ...                                                  ...
# 15076                                     Kandivali West
# 15077                                        Lower Parel
# 15078                                     Kandivali West
# 15079                                         Malad West
# 15080                                                NaN
#
#                                                      URL PAGE NO  \
# 0      https://www.zomato.com/mumbai/hitchki-bandra-k...       1
# 1      https://www.zomato.com/mumbai/baba-falooda-mah...       1
# 2      https://www.zomato.com/mumbai/chin-chin-chu-ju...       1
# 3      https://www.zomato.com/mumbai/butterfly-high-b...       1
# 4      https://www.zomato.com/mumbai/bkc-dive-bandra-...       1
# ...                                                  ...     ...
# 15076  https://www.zomato.com/mumbai/hari-om-snack-ba...      99
# 15077  https://www.zomato.com/mumbai/pitaburg-lower-p...      99
# 15078  https://www.zomato.com/mumbai/uncha-otlawala-1...      99
# 15079  https://www.zomato.com/mumbai/mandarin-panda-m...      99
# 15080                                                NaN     NaN
#
#           CUSINE TYPE                                         TIMING  \
# 0       Casual Dining                       12noon to 130am(Mon-Sun)
# 1      Dessert Parlor                            2pm to 1am(Mon-Sun)
# 2       Casual Dining                         12noon to 1am(Mon-Sun)
# 3                 Bar                       12noon to 130am(Mon-Sun)
# 4                 Bar                         1130am to 1am(Mon-Sun)
# ...               ...                                            ...
# 15076     Quick Bites                         11am to 230am(Mon-Sun)
# 15077            none  11am to 11pm(Mon,Tue,Wed,Thu,Sun),11am to ...
# 15078  Dessert Parlor                         9am to 1230AM(Mon-Sun)
# 15079            none            12noon to 330pm,7pm to 1am(Mon-Sun)
# 15080             NaN                                            NaN
#
#        RATING_TYPE RATING VOTES
# 0        Excellent    4.9  3529
# 1        Very Good    4.4  1723
# 2        Very Good    4.2   337
# 3        Very Good    4.3  1200
# 4      Veľmi dobré    4.4  5995
# ...            ...    ...   ...
# 15076         Good    3.7    64
# 15077      Average    3.4    99
# 15078         Good    3.5    29
# 15079         Good    3.7   121
# 15080          NaN    NaN   NaN
#
# [15081 rows x 12 columns]

# %%
#Displaying top 5 records
raw_df.head()
# Out:
#              NAME PRICE                                    CUSINE_CATEGORY  \
# 0         Hitchki  1200  Modern Indian,North Indian,Chinese,Momos,Birya...
# 1    Baba Falooda   400                       Desserts,Ice Cream,Beverages
# 2   Chin Chin Chu  1800                                      Asian,Chinese
# 3  Butterfly High  1000                                      Modern Indian
# 4       BKC  DIVE  1200                   North Indian,Chinese,Continental
#
#      CITY                                             REGION  \
# 0  Mumbai  First International Financial Centre-- Bandra ...
# 1  Mumbai                                              Mahim
# 2  Mumbai                                               Juhu
# 3  Mumbai                               Bandra Kurla Complex
# 4  Mumbai                               Bandra Kurla Complex
#
#                                                  URL PAGE NO     CUSINE TYPE  \
# 0  https://www.zomato.com/mumbai/hitchki-bandra-k...       1   Casual Dining
# 1  https://www.zomato.com/mumbai/baba-falooda-mah...       1  Dessert Parlor
# 2  https://www.zomato.com/mumbai/chin-chin-chu-ju...       1   Casual Dining
# 3  https://www.zomato.com/mumbai/butterfly-high-b...       1             Bar
# 4  https://www.zomato.com/mumbai/bkc-dive-bandra-...       1             Bar
#
#                      TIMING  RATING_TYPE RATING VOTES
# 0  12noon to 130am(Mon-Sun)    Excellent    4.9  3529
# 1       2pm to 1am(Mon-Sun)    Very Good    4.4  1723
# 2    12noon to 1am(Mon-Sun)    Very Good    4.2   337
# 3  12noon to 130am(Mon-Sun)    Very Good    4.3  1200
# 4    1130am to 1am(Mon-Sun)  Veľmi dobré    4.4  5995

# %%
#Getting basic information about dataset, returns number of rows and columns
raw_df.shape
# Out:
# (15081, 12)

# %%
#Getting column names, their datatypes, null values if any along with its count
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15081 entries, 0 to 15080
# Data columns (total 12 columns):
# NAME               15081 non-null object
# PRICE              15080 non-null object
# CUSINE_CATEGORY    15079 non-null object
# CITY               15080 non-null object
# REGION             15080 non-null object
# URL                15080 non-null object
# PAGE NO            15080 non-null object
# CUSINE TYPE        15080 non-null object
# TIMING             15015 non-null object
# RATING_TYPE        15080 non-null object
# RATING             15080 non-null object
# VOTES              15080 non-null object
# dtypes: object(12)
# memory usage: 1.4+ MB

# %%
#To get overall information about the dataset (columns present and values)
raw_df.describe()
# Out:
#          NAME  PRICE  CUSINE_CATEGORY    CITY  REGION    URL  PAGE NO  \
# count   15081  15080            15079   15080   15080  15080    15080
# unique  12720     67             3183       2     241  13823      944
# top      NAME    400  CUSINE_CATEGORY  Mumbai  REGION    URL  PAGE NO
# freq      942   2042              942   14138     942    942      942
#
#         CUSINE TYPE                 TIMING RATING_TYPE RATING  VOTES
# count         15080                  15015       15080  15080  15080
# unique           23                   2551          32     35   1124
# top     Quick Bites  11am to 11pm(Mon-Sun)     Average      -      -
# freq           5262                   1192        5112   2360   2360

# %%
#Getting column names
raw_df.columns
# Out:
# Index(['NAME', 'PRICE', 'CUSINE_CATEGORY', 'CITY', 'REGION', 'URL', 'PAGE NO',
#        'CUSINE TYPE', 'TIMING', 'RATING_TYPE', 'RATING', 'VOTES'],
#       dtype='object')

# %%
#Identifying redundant rows of data and storing it to separate column named wrong_data in dataframe
wrong_data=raw_df['PAGE NO'] == 'PAGE NO'
raw_df[wrong_data]
# Out:
#        NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE  \
# 15     NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# 31     NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# 47     NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# 63     NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# 79     NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# ...     ...    ...              ...   ...     ...  ...      ...          ...
# 15000  NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# 15016  NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# 15032  NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# 15048  NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
# 15064  NAME  PRICE  CUSINE_CATEGORY  CITY  REGION  URL  PAGE NO  CUSINE TYPE
#
#        TIMING  RATING_TYPE  RATING  VOTES
# 15     TIMING  RATING_TYPE  RATING  VOTES
# 31     TIMING  RATING_TYPE  RATING  VOTES
# 47     TIMING  RATING_TYPE  RATING  VOTES
# 63     TIMING  RATING_TYPE  RATING  VOTES
# 79     TIMING  RATING_TYPE  RATING  VOTES
# ...       ...          ...     ...    ...
# 15000  TIMING  RATING_TYPE  RATING  VOTES
# 15016  TIMING  RATING_TYPE  RATING  VOTES
# 15032  TIMING  RATING_TYPE  RATING  VOTES
# 15048  TIMING  RATING_TYPE  RATING  VOTES
# 15064  TIMING  RATING_TYPE  RATING  VOTES
#
# [942 rows x 12 columns]

# %%
#Performing negation of wrong_data column and storing remaining columns in dataframe
raw_df=raw_df[~wrong_data]
raw_df
# Out:
#                     NAME PRICE  \
# 0                Hitchki  1200
# 1           Baba Falooda   400
# 2          Chin Chin Chu  1800
# 3         Butterfly High  1000
# 4              BKC  DIVE  1200
# ...                  ...   ...
# 15076  Hari Om Snack Bar   350
# 15077           PitaBurg   400
# 15078     Uncha Otlawala   300
# 15079     Mandarin Panda   400
# 15080                     NaN
#
#                                          CUSINE_CATEGORY    CITY  \
# 0      Modern Indian,North Indian,Chinese,Momos,Birya...  Mumbai
# 1                           Desserts,Ice Cream,Beverages  Mumbai
# 2                                          Asian,Chinese  Mumbai
# 3                                          Modern Indian  Mumbai
# 4                       North Indian,Chinese,Continental  Mumbai
# ...                                                  ...     ...
# 15076                     Fast Food,South Indian,Chinese  Mumbai
# 15077                                 Fast Food,Lebanese  Mumbai
# 15078                                 Desserts,Ice Cream  Mumbai
# 15079                              Desserts,Chinese,Thai  Mumbai
# 15080                                                NaN     NaN
#
#                                                   REGION  \
# 0      First International Financial Centre-- Bandra ...
# 1                                                  Mahim
# 2                                                   Juhu
# 3                                   Bandra Kurla Complex
# 4                                   Bandra Kurla Complex
# ...                                                  ...
# 15076                                     Kandivali West
# 15077                                        Lower Parel
# 15078                                     Kandivali West
# 15079                                         Malad West
# 15080                                                NaN
#
#                                                      URL PAGE NO  \
# 0      https://www.zomato.com/mumbai/hitchki-bandra-k...       1
# 1      https://www.zomato.com/mumbai/baba-falooda-mah...       1
# 2      https://www.zomato.com/mumbai/chin-chin-chu-ju...       1
# 3      https://www.zomato.com/mumbai/butterfly-high-b...       1
# 4      https://www.zomato.com/mumbai/bkc-dive-bandra-...       1
# ...                                                  ...     ...
# 15076  https://www.zomato.com/mumbai/hari-om-snack-ba...      99
# 15077  https://www.zomato.com/mumbai/pitaburg-lower-p...      99
# 15078  https://www.zomato.com/mumbai/uncha-otlawala-1...      99
# 15079  https://www.zomato.com/mumbai/mandarin-panda-m...      99
# 15080                                                NaN     NaN
#
#           CUSINE TYPE                                         TIMING  \
# 0       Casual Dining                       12noon to 130am(Mon-Sun)
# 1      Dessert Parlor                            2pm to 1am(Mon-Sun)
# 2       Casual Dining                         12noon to 1am(Mon-Sun)
# 3                 Bar                       12noon to 130am(Mon-Sun)
# 4                 Bar                         1130am to 1am(Mon-Sun)
# ...               ...                                            ...
# 15076     Quick Bites                         11am to 230am(Mon-Sun)
# 15077            none  11am to 11pm(Mon,Tue,Wed,Thu,Sun),11am to ...
# 15078  Dessert Parlor                         9am to 1230AM(Mon-Sun)
# 15079            none            12noon to 330pm,7pm to 1am(Mon-Sun)
# 15080             NaN                                            NaN
#
#        RATING_TYPE RATING VOTES
# 0        Excellent    4.9  3529
# 1        Very Good    4.4  1723
# 2        Very Good    4.2   337
# 3        Very Good    4.3  1200
# 4      Veľmi dobré    4.4  5995
# ...            ...    ...   ...
# 15076         Good    3.7    64
# 15077      Average    3.4    99
# 15078         Good    3.5    29
# 15079         Good    3.7   121
# 15080          NaN    NaN   NaN
#
# [14139 rows x 12 columns]

# %%
#Dropping columns which are not required for further analysis
raw_df.drop(['URL','PAGE NO','CITY'], axis=1, inplace=True)
# Out:
# C:\Users\sanja\Anaconda3\lib\site-packages\pandas\core\frame.py:4102: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Displaying top 5 records, after removing redundant,unwanted datas
raw_df.head()
# Out:
#              NAME PRICE                                    CUSINE_CATEGORY  \
# 0         Hitchki  1200  Modern Indian,North Indian,Chinese,Momos,Birya...
# 1    Baba Falooda   400                       Desserts,Ice Cream,Beverages
# 2   Chin Chin Chu  1800                                      Asian,Chinese
# 3  Butterfly High  1000                                      Modern Indian
# 4       BKC  DIVE  1200                   North Indian,Chinese,Continental
#
#                                               REGION     CUSINE TYPE  \
# 0  First International Financial Centre-- Bandra ...   Casual Dining
# 1                                              Mahim  Dessert Parlor
# 2                                               Juhu   Casual Dining
# 3                               Bandra Kurla Complex             Bar
# 4                               Bandra Kurla Complex             Bar
#
#                      TIMING  RATING_TYPE RATING VOTES
# 0  12noon to 130am(Mon-Sun)    Excellent    4.9  3529
# 1       2pm to 1am(Mon-Sun)    Very Good    4.4  1723
# 2    12noon to 1am(Mon-Sun)    Very Good    4.2   337
# 3  12noon to 130am(Mon-Sun)    Very Good    4.3  1200
# 4    1130am to 1am(Mon-Sun)  Veľmi dobré    4.4  5995

# %%
#Checking for existence of null records with its count
raw_df.isnull().sum()
# Out:
# NAME                0
# PRICE               1
# CUSINE_CATEGORY     2
# REGION              1
# CUSINE TYPE         1
# TIMING             66
# RATING_TYPE         1
# RATING              1
# VOTES               1
# dtype: int64

# %%
#Checking for a null row
raw_df[raw_df['PRICE'].isnull()]
# Out:
#       NAME PRICE CUSINE_CATEGORY REGION CUSINE TYPE TIMING RATING_TYPE RATING  \
# 15080       NaN             NaN    NaN         NaN    NaN         NaN    NaN
#
#       VOTES
# 15080   NaN

# %%
#Dropping above row from dataset
raw_df.drop(labels=15080, axis=0)
# Out:
#                     NAME PRICE  \
# 0                Hitchki  1200
# 1           Baba Falooda   400
# 2          Chin Chin Chu  1800
# 3         Butterfly High  1000
# 4              BKC  DIVE  1200
# ...                  ...   ...
# 15075    Tirupati Balaji   500
# 15076  Hari Om Snack Bar   350
# 15077           PitaBurg   400
# 15078     Uncha Otlawala   300
# 15079     Mandarin Panda   400
#
#                                          CUSINE_CATEGORY  \
# 0      Modern Indian,North Indian,Chinese,Momos,Birya...
# 1                           Desserts,Ice Cream,Beverages
# 2                                          Asian,Chinese
# 3                                          Modern Indian
# 4                       North Indian,Chinese,Continental
# ...                                                  ...
# 15075                     Chinese,Fast Food,North Indian
# 15076                     Fast Food,South Indian,Chinese
# 15077                                 Fast Food,Lebanese
# 15078                                 Desserts,Ice Cream
# 15079                              Desserts,Chinese,Thai
#
#                                                   REGION     CUSINE TYPE  \
# 0      First International Financial Centre-- Bandra ...   Casual Dining
# 1                                                  Mahim  Dessert Parlor
# 2                                                   Juhu   Casual Dining
# 3                                   Bandra Kurla Complex             Bar
# 4                                   Bandra Kurla Complex             Bar
# ...                                                  ...             ...
# 15075                            Oshiwara-- Andheri West   Casual Dining
# 15076                                     Kandivali West     Quick Bites
# 15077                                        Lower Parel            none
# 15078                                     Kandivali West  Dessert Parlor
# 15079                                         Malad West            none
#
#                                               TIMING  RATING_TYPE RATING VOTES
# 0                           12noon to 130am(Mon-Sun)    Excellent    4.9  3529
# 1                                2pm to 1am(Mon-Sun)    Very Good    4.4  1723
# 2                             12noon to 1am(Mon-Sun)    Very Good    4.2   337
# 3                           12noon to 130am(Mon-Sun)    Very Good    4.3  1200
# 4                             1130am to 1am(Mon-Sun)  Veľmi dobré    4.4  5995
# ...                                              ...          ...    ...   ...
# 15075       8am to 11pm,12midnight to 115am(Mon-Sun)         Good    3.5   267
# 15076                         11am to 230am(Mon-Sun)         Good    3.7    64
# 15077  11am to 11pm(Mon,Tue,Wed,Thu,Sun),11am to ...      Average    3.4    99
# 15078                         9am to 1230AM(Mon-Sun)         Good    3.5    29
# 15079            12noon to 330pm,7pm to 1am(Mon-Sun)         Good    3.7   121
#
# [14138 rows x 9 columns]

# %%
#Replacing null values in all other columns with NA
raw_df.fillna("NA",inplace=True)
# Out:
# C:\Users\sanja\Anaconda3\lib\site-packages\pandas\core\frame.py:4244: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#confirm there are no null records, after replacing with other values
raw_df.isnull().sum()
# Out:
# NAME               0
# PRICE              0
# CUSINE_CATEGORY    0
# REGION             0
# CUSINE TYPE        0
# TIMING             0
# RATING_TYPE        0
# RATING             0
# VOTES              0
# dtype: int64

# %%
# Checking for text values in the column before converting it to numeric datatype
raw_df['RATING'].value_counts()
# Out:
# -          2360
# 3.5        1094
# 3.4        1036
# 3.6         960
# NEW         953
# 3.3         926
# 3.7         917
# 3.2         801
# 3.8         782
# 3.1         734
# 3.0         622
# 3.9         596
# 2.9         409
# 4.0         408
# 2.8         309
# 4.1         298
# 4.2         199
# 2.7         170
# 4.3         148
# 4.4          99
# 2.6          77
# Opening      57
# 4.5          46
# 2.5          39
# 4.6          32
# 2.4          26
# 4.7          13
# 2.3          10
# 2.1           5
# 2.2           4
# 4.8           4
# 4.9           2
# 1.8           1
# NA            1
# 2.0           1
# Name: RATING, dtype: int64

# %%
#Replacing text values with '0'
raw_df['RATING'].replace(to_replace=['-','NEW','Opening'], value='0', inplace=True)
# Out:
# C:\Users\sanja\Anaconda3\lib\site-packages\pandas\core\generic.py:6786: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Checking for text values in 'VOTES' column before converting it to numeric datatype
raw_df['VOTES'].value_counts()
# Out:
# -       2360
# NEW      953
# 4        364
# 5        320
# 6        288
#         ...
# 1480       1
# 2301       1
# 956        1
# 2998       1
# 817        1
# Name: VOTES, Length: 1124, dtype: int64

# %%
#Replacing text values with '0'
raw_df['VOTES'].replace(to_replace=['-','NEW','Opening'], value='0', inplace=True)

# %%
raw_df.dtypes
# Out:
# NAME               object
# PRICE              object
# CUSINE_CATEGORY    object
# REGION             object
# CUSINE TYPE        object
# TIMING             object
# RATING_TYPE        object
# RATING             object
# VOTES              object
# dtype: object

# %%
# Changing Data Type to integer for the numerical columns
raw_df['PRICE'] = raw_df['PRICE'].astype('int64')
raw_df['RATING'] = raw_df['RATING'].astype('float64')
raw_df['VOTES'] = raw_df['VOTES'].astype('int64')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-9e82c58475d7> in <module>
#       1 # Changing Data Type to integer for the numerical columns
# ----> 2 raw_df['PRICE'] = raw_df['PRICE'].astype('int64')
#       3 raw_df['RATING'] = raw_df['RATING'].astype('float64')
#       4 raw_df['VOTES'] = raw_df['VOTES'].astype('int64')
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5880             # else, only a single dtype is given
#    5881             new_data = self._data.astype(
# -> 5882                 dtype=dtype, copy=copy, errors=errors, **kwargs
#    5883             )
#    5884             return self._constructor(new_data).__finalize__(self)
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, **kwargs)
#     579
#     580     def astype(self, dtype, **kwargs):
# --> 581         return self.apply("astype", dtype=dtype, **kwargs)
#     582
#     583     def convert(self, **kwargs):
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#     436                     kwargs[k] = obj.reindex(b_items, axis=axis, copy=align_copy)
#     437
# --> 438             applied = getattr(b, f)(**kwargs)
#     439             result_blocks = _extend_blocks(applied, result_blocks)
#     440
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors, values, **kwargs)
#     557
#     558     def astype(self, dtype, copy=False, errors="raise", values=None, **kwargs):
# --> 559         return self._astype(dtype, copy=copy, errors=errors, values=values, **kwargs)
#     560
#     561     def _astype(self, dtype, copy=False, errors="raise", values=None, **kwargs):
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py in _astype(self, dtype, copy, errors, values, **kwargs)
#     641                     # _astype_nansafe works fine with 1-d only
#     642                     vals1d = values.ravel()
# --> 643                     values = astype_nansafe(vals1d, dtype, copy=True, **kwargs)
#     644
#     645                 # TODO(extension)
#
# ~\Anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy, skipna)
#     705         # work around NumPy brokenness, #1987
#     706         if np.issubdtype(dtype.type, np.integer):
# --> 707             return lib.astype_intsafe(arr.ravel(), dtype).reshape(arr.shape)
#     708
#     709         # if we have a datetime/timedelta array of objects
#
# pandas\_libs\lib.pyx in pandas._libs.lib.astype_intsafe()
#
# ValueError: invalid literal for int() with base 10: 'NA'

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14139 entries, 0 to 15080
# Data columns (total 9 columns):
# NAME               14139 non-null object
# PRICE              14139 non-null object
# CUSINE_CATEGORY    14139 non-null object
# REGION             14139 non-null object
# CUSINE TYPE        14139 non-null object
# TIMING             14139 non-null object
# RATING_TYPE        14139 non-null object
# RATING             14139 non-null object
# VOTES              14139 non-null object
# dtypes: object(9)
# memory usage: 1.7+ MB

# %%
#Getting the count of column values of Timing column
raw_df['TIMING'].value_counts()
# Out:
# 11am to 11pm(Mon-Sun)                                1192
# 11am to 12midnight(Mon-Sun)                           632
# 12noon to 12midnight(Mon-Sun)                         467
# 11am to 1130pm(Mon-Sun)                               309
# 10am to 10pm(Mon-Sun)                                 267
#                                                      ...
# 11am to 10pm(Mon-Fri),11am to 12midnight(Sat-Sun)       1
# Closed(Mon),8am to 9pm(Tue-Sun)                         1
# 11am to 1am(Mon),1130am to 12midnight...                1
# 8am to 230pm,530pm to 11pm(Mon-Sun)                     1
# 11am to 1110pm(Mon-Sun)                                 1
# Name: TIMING, Length: 2551, dtype: int64

# %%
#Splitting the data and storing it in temp_df dataframe
temp_df=raw_df['TIMING'].str.split("(",n=1,expand=True)
temp_df
# Out:
#                                 0                                 1
# 0                 12noon to 130am                          Mon-Sun)
# 1                      2pm to 1am                          Mon-Sun)
# 2                   12noon to 1am                          Mon-Sun)
# 3                 12noon to 130am                          Mon-Sun)
# 4                   1130am to 1am                          Mon-Sun)
# ...                           ...                               ...
# 15076               11am to 230am                          Mon-Sun)
# 15077                11am to 11pm  Mon,Tue,Wed,Thu,Sun),11am to ...
# 15078               9am to 1230AM                          Mon-Sun)
# 15079  12noon to 330pm,7pm to 1am                          Mon-Sun)
# 15080                          NA                              None
#
# [14139 rows x 2 columns]

# %%
#assigning the columns back to raw_df dataframe
raw_df['TIMING'] = temp_df[0]
raw_df['DAYS_OPEN'] = temp_df[1]
raw_df.head()
# Out:
# C:\Users\sanja\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\sanja\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#              NAME PRICE                                    CUSINE_CATEGORY  \
# 0         Hitchki  1200  Modern Indian,North Indian,Chinese,Momos,Birya...
# 1    Baba Falooda   400                       Desserts,Ice Cream,Beverages
# 2   Chin Chin Chu  1800                                      Asian,Chinese
# 3  Butterfly High  1000                                      Modern Indian
# 4       BKC  DIVE  1200                   North Indian,Chinese,Continental
#
#                                               REGION     CUSINE TYPE  \
# 0  First International Financial Centre-- Bandra ...   Casual Dining
# 1                                              Mahim  Dessert Parlor
# 2                                               Juhu   Casual Dining
# 3                               Bandra Kurla Complex             Bar
# 4                               Bandra Kurla Complex             Bar
#
#             TIMING  RATING_TYPE RATING VOTES DAYS_OPEN
# 0  12noon to 130am    Excellent    4.9  3529  Mon-Sun)
# 1       2pm to 1am    Very Good    4.4  1723  Mon-Sun)
# 2    12noon to 1am    Very Good    4.2   337  Mon-Sun)
# 3  12noon to 130am    Very Good    4.3  1200  Mon-Sun)
# 4    1130am to 1am  Veľmi dobré    4.4  5995  Mon-Sun)

# %%
#Removing the bracket character from 'DAYS_OPEN' column and displaying top 5 data
raw_df['DAYS_OPEN']=raw_df['DAYS_OPEN'].str.replace(")",'',regex=True)
raw_df.head()
# Out:
# C:\Users\sanja\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#              NAME PRICE                                    CUSINE_CATEGORY  \
# 0         Hitchki  1200  Modern Indian,North Indian,Chinese,Momos,Birya...
# 1    Baba Falooda   400                       Desserts,Ice Cream,Beverages
# 2   Chin Chin Chu  1800                                      Asian,Chinese
# 3  Butterfly High  1000                                      Modern Indian
# 4       BKC  DIVE  1200                   North Indian,Chinese,Continental
#
#                                               REGION     CUSINE TYPE  \
# 0  First International Financial Centre-- Bandra ...   Casual Dining
# 1                                              Mahim  Dessert Parlor
# 2                                               Juhu   Casual Dining
# 3                               Bandra Kurla Complex             Bar
# 4                               Bandra Kurla Complex             Bar
#
#             TIMING  RATING_TYPE RATING VOTES DAYS_OPEN
# 0  12noon to 130am    Excellent    4.9  3529   Mon-Sun
# 1       2pm to 1am    Very Good    4.4  1723   Mon-Sun
# 2    12noon to 1am    Very Good    4.2   337   Mon-Sun
# 3  12noon to 130am    Very Good    4.3  1200   Mon-Sun
# 4    1130am to 1am  Veľmi dobré    4.4  5995   Mon-Sun

# %%
# Checking for Null records in DAYS_OPEN column
raw_df.isnull().sum()
# Out:
# NAME                 0
# PRICE                0
# CUSINE_CATEGORY      0
# REGION               0
# CUSINE TYPE          0
# TIMING               0
# RATING_TYPE          0
# RATING               0
# VOTES                0
# DAYS_OPEN          161
# dtype: int64

# %%
#Replacing null values with 'NA'
raw_df=raw_df.fillna('NA',inplace=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-27b9c2300fdc> in <module>
#       1 #Replacing null values with 'NA'
# ----> 2 raw_df=raw_df.fillna('NA',inplace=True)
#
# AttributeError: 'NoneType' object has no attribute 'fillna'

# %%
raw_df.info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-176ef383b56b> in <module>
# ----> 1 raw_df.info()
#
# AttributeError: 'NoneType' object has no attribute 'info'

# %%
# Finding those restaurant whose has 0 Rating or Votes and removing them
useless_data = (raw_df['RATING'] == 0.0) | (raw_df['VOTES'] == 0)
raw_df[useless_data]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-d4694612efef> in <module>
#       1 # Finding those restaurant whose has 0 Rating or Votes and removing them
# ----> 2 useless_data = (raw_df['RATING'] == 0.0) | (raw_df['VOTES'] == 0)
#       3 raw_df[useless_data]
#
# TypeError: 'NoneType' object is not subscriptable

# %%
# Performing Negation of the useless dataset and then storing the correct data back in the raw_df DataFrame
# This permamnently remove the wrong data from the original dataframe
raw_df = raw_df[~useless_data]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-81c51e9fcce7> in <module>
#       1 # Performing Negation of the useless dataset and then storing the correct data back in the raw_df DataFrame
#       2 # This permamnently remove the wrong data from the original dataframe
# ----> 3 raw_df = raw_df[~useless_data]
#
# NameError: name 'useless_data' is not defined

# %%
# Checking the unique values in the column
raw_df['RATING_TYPE'].value_counts()

# %%
# Translating the texts into proper English text
raw_df['RATING_TYPE'].replace(to_replace='Excelente' , value='Excellent', inplace=True)
raw_df['RATING_TYPE'].replace(to_replace=['Veľmi dobré','Bardzo dobrze','Muy Bueno','Velmi dobré'] , value='Very Good',
raw_df['RATING_TYPE'].replace(to_replace=['Skvělá volba','Dobrze','Bueno','Buono','Dobré','Bom','Skvělé'] , value='Good
raw_df['RATING_TYPE'].replace(to_replace=['Priemer','Média','Çok iyi'] , value='Average', inplace=True)
raw_df['RATING_TYPE'].replace(to_replace=['Průměr','Promedio','Ortalama','Muito Bom','İyi'] , value='Poor', inplace=Tru
raw_df['RATING_TYPE'].replace(to_replace=['Baik','Biasa','Media','Sangat Baik'] , value='Very Poor', inplace=True)

# %%
# Checking all the values correctly mapped
raw_df['RATING_TYPE'].value_counts()

# %%
raw_df['REGION'].value_counts()

# %%
# Removing the irrelevant text from the Region column
raw_df['REGION'] = raw_df['REGION'].str.replace('[a-zA-Z].+-- ','',regex=True)

# %%
# Removing the West & East from the Region column
raw_df['REGION'] = raw_df['REGION'].str.replace(' West| west| East| east','',regex=True)

# %%
raw_df['REGION'].value_counts()

# %%
# Replacing Small regions with Known region name
raw_df['REGION'] = raw_df['REGION'].str.replace('4 Bungalows|7 Andheri|Azad Nagar|Near Andheri Station|Veera Desai Area
raw_df['REGION'] = raw_df['REGION'].str.replace('Bandra Kurla Complex','Bandra',regex=True)
raw_df['REGION'] = raw_df['REGION'].str.replace('CBD-Belapur','CBD Belapur',regex=True)
raw_df['REGION'] = raw_df['REGION'].str.replace('Girgaon Chowpatty','Chowpatty',regex=True)
raw_df['REGION'] = raw_df['REGION'].str.replace('Dadar Shivaji Park','Dadar',regex=True)
raw_df['REGION'] = raw_df['REGION'].str.replace('Flea Bazaar Café|Kamala Mills Compound','Lower Parel',regex=True)
raw_df['REGION'] = raw_df['REGION'].str.replace('Runwal Green','Mulund',regex=True)
raw_df['REGION'] = raw_df['REGION'].str.replace('Mumbai CST Area','Mumbai Central',regex=True)
raw_df['REGION'] = raw_df['REGION'].str.replace('Kopar Khairane|Seawoods|Turbhe|Ulwe','Navi Mumbai',regex=True)
raw_df['REGION'] = raw_df['REGION'].str.replace('New Panvel|Old Panvel','Panvel',regex=True)
raw_df['REGION'] = raw_df['REGION'].str.replace('Kamothe','Sion',regex=True)
raw_df['REGION'] = raw_df['REGION'].str.replace('Ghodbunder Road|Majiwada','Thane',regex=True)

# %%
# Finding all the duplicate rows
raw_df[raw_df.duplicated()]

# %%
# Dropping all the duplicate rows
raw_df = raw_df.drop_duplicates()

# %%
#Copying cleaned data into new dataframe
zomato_df = raw_df.copy()

# %%
#Displaying top 5 records
zomato_df.head()
